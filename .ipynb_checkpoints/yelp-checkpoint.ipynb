# %%
import requests
import json
from config import api_key
import pandas as pd

# %%
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % api_key}
params = {'price' : '4', 'location' : 'dallas', 'limit': '50'}

req=requests.get(url, params=params, headers=headers)
#print('The status code is {}'.format(req.status_code))
req.json()
print(json.dumps(req.json(), indent=4, sort_keys=True))
# Out:
# {
#     "businesses": [
#         {
#             "alias": "pappas-bros-steakhouse-dallas",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.8668273689937,
#                 "longitude": -96.8977529669342
#             },
#             "display_phone": "(214) 366-2000",
#             "distance": 9592.160920715294,
#             "id": "vOUOAoPRW27oNJFJLhkNNQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/pJjvgTwcEvUcofvyA0r-zQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "10477 Lombardy Ln",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "10477 Lombardy Ln",
#                     "Dallas, TX 75220"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75220"
#             },
#             "name": "Pappas Bros Steakhouse",
#             "phone": "+12143662000",
#             "price": "$$$$",
#             "rating": 4.5,
#             "review_count": 906,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/pappas-bros-steakhouse-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "frank-dallas-2",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.784096,
#                 "longitude": -96.782949
#             },
#             "display_phone": "(214) 997-3306",
#             "distance": 6327.106327712217,
#             "id": "rm5vk91gV42Zvqq5rN387A",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/wisxT0cQ_Yw0aSuD7Ac85w/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "Deep Ellum",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "Deep Ellum",
#                     "Dallas, TX 75226"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75226"
#             },
#             "name": "Frank",
#             "phone": "+12149973306",
#             "price": "$$$$",
#             "rating": 5.0,
#             "review_count": 209,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/frank-dallas-2?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "nick-and-sams-dallas",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.798462335543,
#                 "longitude": -96.8074539666488
#             },
#             "display_phone": "(214) 871-7444",
#             "distance": 4558.469893778069,
#             "id": "IOdz8GcOx8WRKqsK2DCjfw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/MQUeFoubaWCYpSFZ2FHjgA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3008 Maple Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "3008 Maple Ave",
#                     "Dallas, TX 75201"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75201"
#             },
#             "name": "Nick & Sam's",
#             "phone": "+12148717444",
#             "price": "$$$$",
#             "rating": 4.0,
#             "review_count": 1102,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/nick-and-sams-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "fearings-restaurant-dallas",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.7923217865187,
#                 "longitude": -96.8037504570431
#             },
#             "display_phone": "(214) 922-4848",
#             "distance": 5203.88099973816,
#             "id": "8y4511YMVKwfg9z2JzWKkA",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/w3duhbpIUOZycWo8HwfxHg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2121 McKinney Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "2121 McKinney Ave",
#                     "Dallas, TX 75201"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75201"
#             },
#             "name": "Fearing's Restaurant",
#             "phone": "+12149224848",
#             "price": "$$$$",
#             "rating": 4.0,
#             "review_count": 527,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/fearings-restaurant-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "nobu-dallas-dallas-3",
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "asianfusion",
#                     "title": "Asian Fusion"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.794194821906,
#                 "longitude": -96.80394603366
#             },
#             "display_phone": "(214) 252-7000",
#             "distance": 4997.102321989811,
#             "id": "CNbNYbDVKUP8Cuv9RKTnvA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/pUmGhMb2v4lfyxohk4iV4g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "400 Crescent Ct",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "400 Crescent Ct",
#                     "Dallas, TX 75201"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75201"
#             },
#             "name": "Nobu Dallas",
#             "phone": "+12142527000",
#             "price": "$$$$",
#             "rating": 4.0,
#             "review_count": 506,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/nobu-dallas-dallas-3?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "stephan-pyles-flora-street-cafe-dallas-2",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.789598,
#                 "longitude": -96.797698
#             },
#             "display_phone": "(214) 580-7000",
#             "distance": 5504.478683237675,
#             "id": "N3EXE0yJp9RCwd-5B-fukg",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/vPQWtvq0Vr5MAQSP8FUyKw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2330 Flora St",
#                 "address2": "Ste 150",
#                 "address3": null,
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "2330 Flora St",
#                     "Ste 150",
#                     "Dallas, TX 75201"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75201"
#             },
#             "name": "Stephan Pyles Flora Street Cafe",
#             "phone": "+12145807000",
#             "price": "$$$$",
#             "rating": 4.0,
#             "review_count": 156,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/stephan-pyles-flora-street-cafe-dallas-2?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "s\u0113r-steak-and-spirits-dallas-2",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.8001625852709,
#                 "longitude": -96.8290370343933
#             },
#             "display_phone": "(214) 761-7479",
#             "distance": 5077.799305583481,
#             "id": "tqUccoZFHMusC5ooOEuTQw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/1tdoecCi5bNmmbIjQT3jHQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2201 N Stemmons Fwy",
#                 "address2": "Fl 27",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "2201 N Stemmons Fwy",
#                     "Fl 27",
#                     "Dallas, TX 75207"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75207"
#             },
#             "name": "S\u0112R Steak & Spirits",
#             "phone": "+12147617479",
#             "price": "$$$$",
#             "rating": 3.5,
#             "review_count": 277,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/s%C4%93r-steak-and-spirits-dallas-2?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "the-mansion-restaurant-dallas-9",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.8038549073665,
#                 "longitude": -96.8069296999695
#             },
#             "display_phone": "(214) 443-4747",
#             "distance": 3958.121563449412,
#             "id": "GuTE4IPiTWDERwc_qJmSyg",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/1DfD1uiry_v4j5va1zgm6w/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2821 Turtle Creek Blvd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "2821 Turtle Creek Blvd",
#                     "Dallas, TX 75219"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75219"
#             },
#             "name": "The Mansion Restaurant",
#             "phone": "+12144434747",
#             "price": "$$$$",
#             "rating": 3.5,
#             "review_count": 168,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/the-mansion-restaurant-dallas-9?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "the-french-room-dallas-4",
#             "categories": [
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.7799503642988,
#                 "longitude": -96.7997499679799
#             },
#             "display_phone": "(214) 651-3615",
#             "distance": 6571.259420346397,
#             "id": "DFDzmTV_piFkr7AeKO8E6A",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/tjXe6qhRNZKrM28FYXbevg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1321 Commerce St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "1321 Commerce St",
#                     "Dallas, TX 75202"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75202"
#             },
#             "name": "The French Room",
#             "phone": "+12146513615",
#             "price": "$$$$",
#             "rating": 4.0,
#             "review_count": 77,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/the-french-room-dallas-4?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "the-mansion-bar-dallas",
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.80412,
#                 "longitude": -96.8073217
#             },
#             "display_phone": "(214) 443-4747",
#             "distance": 3934.720304944057,
#             "id": "bTM2Owr7FVrIhhdhS7z5jw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Sr_PLoKpsG1t_bd6IvCQ0A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2821 Turtle Creek Blvd",
#                 "address2": "",
#                 "address3": "Rosewood Mansion On Turtle Creek",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "2821 Turtle Creek Blvd",
#                     "Rosewood Mansion On Turtle Creek",
#                     "Dallas, TX 75219"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75219"
#             },
#             "name": "The Mansion Bar",
#             "phone": "+12144434747",
#             "price": "$$$$",
#             "rating": 4.0,
#             "review_count": 44,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/the-mansion-bar-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "fine-china-dallas",
#             "categories": [
#                 {
#                     "alias": "chinese",
#                     "title": "Chinese"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.7806801516603,
#                 "longitude": -96.7946199067459
#             },
#             "display_phone": "(469) 320-8996",
#             "distance": 6513.217543373203,
#             "id": "NaSgGkl78z3Pb9UUUf_YZQ",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/PY1QLydq8f__urHsIfl3EA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1914 Commerce St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "1914 Commerce St",
#                     "Dallas, TX 75202"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75202"
#             },
#             "name": "Fine China",
#             "phone": "+14693208996",
#             "price": "$$$$",
#             "rating": 3.5,
#             "review_count": 76,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/fine-china-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "jk-chocolate-dallas",
#             "categories": [
#                 {
#                     "alias": "desserts",
#                     "title": "Desserts"
#                 },
#                 {
#                     "alias": "giftshops",
#                     "title": "Gift Shops"
#                 },
#                 {
#                     "alias": "chocolate",
#                     "title": "Chocolatiers & Shops"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.8509355,
#                 "longitude": -96.8295687
#             },
#             "display_phone": "(214) 350-0427",
#             "distance": 3017.3009884508187,
#             "id": "MMqklerr5-aT-lhm7ZTIaQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/ztP0Uv36Th5mSauB4s7q2A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4710 W Lovers Ln",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "4710 W Lovers Ln",
#                     "Dallas, TX 75209"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75209"
#             },
#             "name": "JK CHOCOLATE",
#             "phone": "+12143500427",
#             "price": "$$$$",
#             "rating": 4.5,
#             "review_count": 13,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/jk-chocolate-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "crescent-club-dallas",
#             "categories": [
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.7936202,
#                 "longitude": -96.8040948
#             },
#             "display_phone": "(214) 871-8555",
#             "distance": 5056.917068168876,
#             "id": "XrLngky-WL2t2SATLsQsMQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/RL4RLJ5vLIPGG8Z32pSNZQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "200 Crescent Ct",
#                 "address2": "Ste 1700",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "200 Crescent Ct",
#                     "Ste 1700",
#                     "Dallas, TX 75201"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75201"
#             },
#             "name": "Crescent Club",
#             "phone": "+12148718555",
#             "price": "$$$$",
#             "rating": 3.5,
#             "review_count": 27,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/crescent-club-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "au-bon-pain-dallas-7",
#             "categories": [
#                 {
#                     "alias": "cafes",
#                     "title": "Cafes"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.9132144,
#                 "longitude": -96.7732206
#             },
#             "display_phone": "(972) 566-6880",
#             "distance": 8632.93192703255,
#             "id": "CzyWYDC49_HxGxjHCsx_Rg",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/a88zqsWhMzc8Crg5u6LpAQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "7777 Forest Ln",
#                 "address2": "Ste D-210",
#                 "address3": "Medical City Dallas,",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "7777 Forest Ln",
#                     "Ste D-210",
#                     "Medical City Dallas,",
#                     "Dallas, TX 75230"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75230"
#             },
#             "name": "Au Bon Pain",
#             "phone": "+19725666880",
#             "price": "$$$$",
#             "rating": 3.0,
#             "review_count": 5,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/au-bon-pain-dallas-7?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "graileys-dallas",
#             "categories": [
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.79371,
#                 "longitude": -96.81647
#             },
#             "display_phone": "(214) 741-1855",
#             "distance": 5262.174553533167,
#             "id": "Z23bDCla91SoSwXaFUqgTQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Kh7KpxiA2kU3wsInypLUxw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1544 Edison St",
#                 "address2": null,
#                 "address3": null,
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "1544 Edison St",
#                     "Dallas, TX 75207"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75207"
#             },
#             "name": "Graileys",
#             "phone": "+12147411855",
#             "price": "$$$$",
#             "rating": 5.0,
#             "review_count": 1,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/graileys-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "crispy-chicken-and-rice-dallas-2",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.74287,
#                 "longitude": -96.83437
#             },
#             "display_phone": "(214) 941-5877",
#             "distance": 11151.388893594605,
#             "id": "-KYoe0Mw0m69OSKICRlYXg",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/3YT4oZnr1ubkWkaMRMgqfQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "704 W Jefferson Blvd",
#                 "address2": null,
#                 "address3": null,
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "704 W Jefferson Blvd",
#                     "Dallas, TX 75208"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75208"
#             },
#             "name": "Crispy Chicken & Rice",
#             "phone": "+12149415877",
#             "price": "$$$$",
#             "rating": 4.0,
#             "review_count": 2,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/crispy-chicken-and-rice-dallas-2?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "fresh-market-the-pob-ii-dallas-3",
#             "categories": [
#                 {
#                     "alias": "buffets",
#                     "title": "Buffets"
#                 },
#                 {
#                     "alias": "salad",
#                     "title": "Salad"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.81686,
#                 "longitude": -96.844856
#             },
#             "display_phone": "(214) 879-0473",
#             "distance": 4836.082343809594,
#             "id": "pZHsCcX43OiJ2KnfoZtXrA",
#             "image_url": "",
#             "is_closed": false,
#             "location": {
#                 "address1": "5939 Harry Hines Blvd",
#                 "address2": "Ste 100",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "5939 Harry Hines Blvd",
#                     "Ste 100",
#                     "Dallas, TX 75235"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75235"
#             },
#             "name": "Fresh Market @ the POB II",
#             "phone": "+12148790473",
#             "price": "$$$$",
#             "rating": 2.5,
#             "review_count": 5,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/fresh-market-the-pob-ii-dallas-3?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "fresco-deli-dallas",
#             "categories": [
#                 {
#                     "alias": "delis",
#                     "title": "Delis"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.92446,
#                 "longitude": -96.80246
#             },
#             "display_phone": "(972) 233-2067",
#             "distance": 9375.611113233828,
#             "id": "5pdZ-bh_5nnQkYT9sg0p5A",
#             "image_url": "",
#             "is_closed": false,
#             "location": {
#                 "address1": "12900 Preston Rd",
#                 "address2": "Ste 113",
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "12900 Preston Rd",
#                     "Ste 113",
#                     "Dallas, TX 75230"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75230"
#             },
#             "name": "Fresco Deli",
#             "phone": "+19722332067",
#             "price": "$$$$",
#             "rating": 3.0,
#             "review_count": 1,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/fresco-deli-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "carpe-diem-lounge-dallas",
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.78052,
#                 "longitude": -96.80089
#             },
#             "display_phone": "(214) 653-1301",
#             "distance": 6515.8467535136315,
#             "id": "s7D57CAhjTKlJrAoKdZrxg",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/djMqtdLs8NSHMwQiRuLa4g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1301 Main St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Dallas",
#                 "country": "US",
#                 "display_address": [
#                     "1301 Main St",
#                     "Dallas, TX 75202"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75202"
#             },
#             "name": "Carpe Diem Lounge",
#             "phone": "+12146531301",
#             "price": "$$$$",
#             "rating": 1.5,
#             "review_count": 2,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/carpe-diem-lounge-dallas?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         },
#         {
#             "alias": "universal-rocks-garland",
#             "categories": [
#                 {
#                     "alias": "hottubandpool",
#                     "title": "Hot Tub & Pool"
#                 },
#                 {
#                     "alias": "reptileshops",
#                     "title": "Reptile Shops"
#                 },
#                 {
#                     "alias": "aquariums",
#                     "title": "Aquariums"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 32.904868038255,
#                 "longitude": -96.6965602883606
#             },
#             "display_phone": "(972) 412-7179",
#             "distance": 12160.035423956599,
#             "id": "2vsWEEbtV16SX0896y4iCQ",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/cR42wmYXw8dBKVOoj5lUJA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "805 Shepherd Dr",
#                 "address2": null,
#                 "address3": null,
#                 "city": "Garland",
#                 "country": "US",
#                 "display_address": [
#                     "805 Shepherd Dr",
#                     "Garland, TX 75042"
#                 ],
#                 "state": "TX",
#                 "zip_code": "75042"
#             },
#             "name": "Universal Rocks",
#             "phone": "+19724127179",
#             "price": "$$$$",
#             "rating": 1.5,
#             "review_count": 3,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/universal-rocks-garland?adjust_creative=nwvx0c98FOGxzKXJkt3pgg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nwvx0c98FOGxzKXJkt3pgg"
#         }
#     ],
#     "region": {
#         "center": {
#             "latitude": 32.839043482398054,
#             "longitude": -96.800537109375
#         }
#     },
#     "total": 20
# }

# %%
parsed = json.loads(req.text)
reviews = parsed["businesses"]

# %%
#df = pd.DataFrame(req)
#pd.read_json(test2)
test2
